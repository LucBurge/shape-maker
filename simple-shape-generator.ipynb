# %%
#Takes user input for shape type
print("Choose a shape!")
print("1 - Left-sided triangle")
print("2 - Right-sided triangle")
print("3 - Diamond")
shape = int(input("Select an option (1-3): "))

#Takes user input for shape width (in no. characters)
width = int(input("Enter the width of your shape (in number of characters): "))

#Takes user input for character to build shape from
char = input("Enter a character to build a shape from: ")
print()

#Displays a left-sided triangle using user specifications
if shape == 1: 
    for A in range(1,width):
        print(A * char + (((width-1)*2)*A)*" ")    

#Displays a right-sided triangle using user specifications
if shape == 2: 
    for i in range(0,width): 

        for j in range(0,i):
            print(" ", end="")

        for k in range(0,width-i):
            print(char, end="")
        print()

#Displays a diamond using user specification
if  shape == 3:
#top triangle
    k = 0
    for i in range(1, width + 1): 
    # print spaces 
        for j in range (1, (width - i) + 1): 
            print(end = " ") 

        while k != (2 * i - 1):
            print(char, end = "")
            k = k + 1
        k = 0

        print()  
 
#bottom triangle
    k = 2
    m = 1
    for i in range(1, width): 
    # print spaces 
        for j in range (1, k):
            print(end = " ") 
        k = k + 1

        while m <= (2 * (width - i) - 1): 
            print(char, end = "") 
            m = m + 1
        m = 1
        
        print()
# Out:
# Choose a shape!
# 1 - Left-sided triangle
# 2 - Right-sided triangle
# 3 - Diamond
# Select an option (1-3): 3
# Enter the width of your shape (in number of characters): 9
# Enter a character to build a shape from: &
#
#         &
#        &&&
#       &&&&&
#      &&&&&&&
#     &&&&&&&&&
#    &&&&&&&&&&&
#   &&&&&&&&&&&&&
#  &&&&&&&&&&&&&&&
# &&&&&&&&&&&&&&&&&
#  &&&&&&&&&&&&&&&
#   &&&&&&&&&&&&&
#    &&&&&&&&&&&
#     &&&&&&&&&
#      &&&&&&&
#       &&&&&
#        &&&
#         &
